# %%
from PIL import Image
import os
import pandas as pd

# %%
df=pd.DataFrame({'name':os.listdir()[2:],'width':list(map(lambda x: Image.open(x).size[0],os.listdir()[2:])),'height':list(map(lambda x: Image.open(x).size[1],os.listdir()[2:]))})
df
# Out:
#                                                   name  width  height
# 0    10820409-brno-czech-republic-august-14-valenti...    863    1300
# 1                                          1315637.jpg   1300     867
# 2                                       137050.big.jpg   1200     900
# 3    1428684178125_motogp_bandiera_rossa_ad_austin_...    576     324
# 4    1586160025_Dorna-CEO-no-longer-excludes-comple...    600     315
# ..                                                 ...    ...     ...
# 222  yannis-papanastasopoulos-if_29seD7tA-unsplash.jpg   5365    3577
# 223                  zane-lee-toi9RoUqco8-unsplash.jpg   4016    6016
# 224               zhang-kaiyv-MmHySVT13s4-unsplash.jpg   4000    6000
# 225        zo-razafindramamba-4uY4opCcLqo-unsplash.jpg   4000    6000
# 226                                              ù.jpg   1300     866
#
# [227 rows x 3 columns]

# %%
f=df.sort_values('height').head(15)['name'].values
df.sort_values('height').head(15)
# for i in f:
#     os.remove(i)
# Out:
#                                                   name  width  height
# 173                         red-flag-with-no-waves.jpg    550     309
# 4    1586160025_Dorna-CEO-no-longer-excludes-comple...    600     315
# 3    1428684178125_motogp_bandiera_rossa_ad_austin_...    576     324
# 10                             5b9bede96faaa.image.jpg    400     358
# 122             Marc-Marquez-Alex-Rins-Yellow-Flag.jpg    678     381
# 31                                      China-flag.jpg    533     400
# 124  marco-simoncelli-hand-signed-checker_1_62e7e76...    302     400
# 156          MotoGP-Motorcycle-Racing-Explained-15.jpg    600     403
# 9                                           564188.jpg    615     405
# 69                   gettyimages-865357134-612x612.jpg    612     408
# 84   how-motogp-bikes-are-being-timed-and-the-flags...    728     410
# 139                     MattCrossan-e1569408744188.jpg    475     415
# ...
